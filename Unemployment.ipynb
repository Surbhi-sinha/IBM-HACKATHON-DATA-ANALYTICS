# %%
import pandas as pd
import numpy as np
df = pd.read_csv('Unemployment_rate.csv')

year = df.FREQUENCY.unique()
print(len(year) , year)

df.info()
# Out:
# 3 ['A' 'Q' 'M']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67052 entries, 0 to 67051
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LOCATION    67052 non-null  object
#  1   INDICATOR   67052 non-null  object
#  2   SUBJECT     67052 non-null  object
#  3   MEASURE     67052 non-null  object
#  4   FREQUENCY   67052 non-null  object
#  5   TIME        67052 non-null  object
#  6   Value       67052 non-null  float64
#  7   Flag Codes  4263 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 4.1+ MB

# %%
df = df[df.FREQUENCY == 'A']
df['TIME'] = df['TIME'].astype('int64')
df.info()
df.count()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4135 entries, 0 to 66505
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LOCATION    4135 non-null   object
#  1   INDICATOR   4135 non-null   object
#  2   SUBJECT     4135 non-null   object
#  3   MEASURE     4135 non-null   object
#  4   FREQUENCY   4135 non-null   object
#  5   TIME        4135 non-null   int64
#  6   Value       4135 non-null   float64
#  7   Flag Codes  323 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 290.7+ KB
# LOCATION      4135
# INDICATOR     4135
# SUBJECT       4135
# MEASURE       4135
# FREQUENCY     4135
# TIME          4135
# Value         4135
# Flag Codes     323
# dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np
def draw(country):
    
    d1 = df.loc[(df['LOCATION'] == country)]
    x = d1['TIME']
    y = d1['Value']
    x = [str(i) for i in x]
    plt.figure(figsize=(10,5))
    plt.xlabel('YEAR', fontsize = 20)
    plt.ylabel('VALUE', fontsize = 20)
    plt.title(country, fontsize = 50)
    plt.bar(x, y, label = country, width = 0.4)
    plt.legend()
    plt.xticks(rotation = 90)
    plt.show()

# %%
countries = df.LOCATION.unique()
print(countries)
print(len(countries))
for country in countries:
      draw(country)
# Out:
# ['AUS' 'AUT' 'BEL' 'CAN' 'CZE' 'DNK' 'FIN' 'FRA' 'DEU' 'GRC' 'HUN' 'ISL'
#  'IRL' 'ITA' 'JPN' 'KOR' 'LUX' 'MEX' 'NLD' 'NZL' 'NOR' 'POL' 'PRT' 'SVK'
#  'ESP' 'SWE' 'CHE' 'TUR' 'GBR' 'USA' 'CHL' 'EST' 'ISR' 'SVN' 'OECD' 'G-7'
#  'EA19' 'LVA' 'LTU' 'COL' 'EU27_2020' 'CRI']
# 42
