# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('Long_term_unemployment_rate.csv')
df.head(20)
# Out:
#    LOCATION INDICATOR SUBJECT   MEASURE FREQUENCY  TIME      Value  Flag Codes
# 0       AUS   LTUNEMP     TOT  PC_UNEMP         A  1978  14.420246         NaN
# 1       AUS   LTUNEMP     TOT  PC_UNEMP         A  1979  18.128151         NaN
# 2       AUS   LTUNEMP     TOT  PC_UNEMP         A  1980  19.175518         NaN
# 3       AUS   LTUNEMP     TOT  PC_UNEMP         A  1981  19.501123         NaN
# 4       AUS   LTUNEMP     TOT  PC_UNEMP         A  1982  18.759181         NaN
# 5       AUS   LTUNEMP     TOT  PC_UNEMP         A  1983  25.211608         NaN
# 6       AUS   LTUNEMP     TOT  PC_UNEMP         A  1984  31.016118         NaN
# 7       AUS   LTUNEMP     TOT  PC_UNEMP         A  1985  30.767980         NaN
# 8       AUS   LTUNEMP     TOT  PC_UNEMP         A  1986  27.610003         NaN
# 9       AUS   LTUNEMP     TOT  PC_UNEMP         A  1987  28.007436         NaN
# 10      AUS   LTUNEMP     TOT  PC_UNEMP         A  1988  27.770045         NaN
# ...

# %%
countries = df.LOCATION.unique()
print(countries)
# Out:
# ['AUS' 'AUT' 'BEL' 'CAN' 'CZE' 'DNK' 'FIN' 'FRA' 'DEU' 'GRC' 'HUN' 'ISL'
#  'IRL' 'ITA' 'JPN' 'KOR' 'LUX' 'MEX' 'NLD' 'NZL' 'NOR' 'POL' 'PRT' 'SVK'
#  'ESP' 'SWE' 'CHE' 'TUR' 'GBR' 'USA' 'G7M' 'BGR' 'HRV' 'CYP' 'EST' 'ISR'
#  'LVA' 'LTU' 'MKD' 'MLT' 'RUS' 'SVN' 'ZAF' 'OECD' 'ROU' 'COL' 'CRI' 'NAM'
#  'EU27']

# %%
subject = df.SUBJECT.unique()
print(len(subject) , subject)
# Out:
# 1 ['TOT']

# %%
frq = df.FREQUENCY.unique()
print(len(frq) , frq)
# Out:
# 1 ['A']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1559 entries, 0 to 1558
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LOCATION    1559 non-null   object
#  1   INDICATOR   1559 non-null   object
#  2   SUBJECT     1559 non-null   object
#  3   MEASURE     1559 non-null   object
#  4   FREQUENCY   1559 non-null   object
#  5   TIME        1559 non-null   int64
#  6   Value       1559 non-null   float64
#  7   Flag Codes  0 non-null      float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 97.6+ KB

# %%
import numpy as np
def draw(country):
    
    d1 = df.loc[(df['LOCATION'] == country)]
    x = d1['TIME']
    y = d1['Value']
    x = [str(i) for i in x]
    plt.figure(figsize=(10,5))
    plt.xlabel('YEAR', fontsize = 20)
    plt.ylabel('VALUE', fontsize = 20)
    plt.title(country, fontsize = 50)
    plt.bar(x, y, label = country, width = 0.4)
    plt.legend()
    plt.xticks(rotation = 90)
    plt.show()
#     fig, ax = plt.subplots()
    
#     ax.bar(x, y, width=1, edgecolor="white", linewidth=0.7)

#    #  ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
#    #     ylim=(0, 8), yticks=np.arange(1, 8))

#     plt.show()

# %%
for country in countries:
      draw(country)
